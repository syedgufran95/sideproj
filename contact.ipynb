# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\MACHINE\Documents\5th sem\internship\contact\Gowalla_totalCheckins.txt" , names=['row','Date','Lat','long','loc id'] ,delimiter='\t')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             row                  Date        Lat       long   loc id
# 0             0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
# 1             0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 2             0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 3             0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 4             0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# ...         ...                   ...        ...        ...      ...
# 6442887  196578  2010-06-11T13:32:26Z  51.742988  -0.488065   906885
# 6442888  196578  2010-06-11T13:26:45Z  51.746492  -0.490780   965121
# 6442889  196578  2010-06-11T13:26:34Z  51.741916  -0.496729  1174322
# 6442890  196585  2010-10-08T21:01:49Z  50.105516   8.571525   471724
# 6442891  196585  2010-10-07T17:39:18Z  50.027812   8.785098  4555073
#
# [6442892 rows x 5 columns]>

# %%
df_100=df.head(100)
print(df_100)
# Out:
#     row                  Date        Lat       long   loc id
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# ..  ...                   ...        ...        ...      ...
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
#
# [100 rows x 5 columns]

# %%
#splits date and time into 2 columns

# %%
def conv(df_100):
    #df_100['Time']=pd.to_datetime(df['Date']).dt.time
    df_100['Dates'] = pd.to_datetime(df['Date'])
    return df_100
    print(df_100)
df_100=conv(df_100)
# Out:
# <ipython-input-78-5fff3a5f6b96>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_100['Dates'] = pd.to_datetime(df['Date'])

# %%
print(df_100)
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates
# 99 2010-08-21 18:10:00+00:00
# 98 2010-08-23 14:45:49+00:00
# 97 2010-08-24 16:26:53+00:00
# 96 2010-08-24 17:33:20+00:00
# 95 2010-08-25 02:03:08+00:00
# ..                       ...
# ...

# %%
#df_100.set_index("Date",inplace=True)

# %%
df_100.sort_values('Date',inplace=True)
# Out:
# <ipython-input-60-fe0bd6fbd25e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_100.sort_values('Date',inplace=True)

# %%
df_100
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates
# 99 2010-08-21 18:10:00+00:00
# 98 2010-08-23 14:45:49+00:00
# 97 2010-08-24 16:26:53+00:00
# 96 2010-08-24 17:33:20+00:00
# 95 2010-08-25 02:03:08+00:00
# ..                       ...
# ...

# %%
def fun(fromdate,fromtime,todate,totime):
    fromd=fromdate+fromtime
    tod=todate+totime
    print(df_100.loc[(df_100['Dates'] > fromd) & (df_100['Dates'] <= tod)])
    
    
fun('2010-9-1', ' 5:00:00','2010-10-15',' 22:02:11')
# Out:
#     row                  Date        Lat       long   loc id  \
# 79    0  2010-09-01T22:36:33Z  30.310153 -97.740158  1067829
# 78    0  2010-09-03T00:28:30Z  30.268696 -97.745615     9313
# 77    0  2010-09-04T03:14:33Z  30.266891 -97.745686     9223
# 76    0  2010-09-04T21:32:40Z  30.244860 -97.757163    18417
# 75    0  2010-09-05T17:33:43Z  30.234214 -97.757571  1576090
# ..  ...                   ...        ...        ...      ...
# 9     0  2010-10-12T15:19:03Z  30.269103 -97.749395   420315
# 8     0  2010-10-12T15:57:20Z  30.281120 -97.745211   153505
# 7     0  2010-10-12T19:44:40Z  30.269103 -97.749395   420315
# 6     0  2010-10-12T22:02:11Z  30.267910 -97.749312    21714
# 5     0  2010-10-12T23:58:03Z  30.261599 -97.758581    15372
#
#                        Dates
# 79 2010-09-01 22:36:33+00:00
# 78 2010-09-03 00:28:30+00:00
# 77 2010-09-04 03:14:33+00:00
# 76 2010-09-04 21:32:40+00:00
# 75 2010-09-05 17:33:43+00:00
# ..                       ...
# ...

# %%
test=df_100.copy()

# %%
test.reset_index
# Out:
# <bound method DataFrame.reset_index of     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates
# 99 2010-08-21 18:10:00+00:00
# 98 2010-08-23 14:45:49+00:00
# 97 2010-08-24 16:26:53+00:00
# 96 2010-08-24 17:33:20+00:00
# 95 2010-08-25 02:03:08+00:00
# ...

# %%
test["df"]=0

# %%
test['Dates'] = (df['Dates'] - df['Dates'].shift().fillna(pd.to_datetime("00:00:00", format="%H:%M:%S")))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dates'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-afa2869690a8> in <module>
# ...

# %%
test
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates  df
# 99 2010-08-21 18:10:00+00:00   0
# 98 2010-08-23 14:45:49+00:00   0
# 97 2010-08-24 16:26:53+00:00   0
# 96 2010-08-24 17:33:20+00:00   0
# 95 2010-08-25 02:03:08+00:00   0
# ...

# %%
test["df"]=test.Dates

# %%
test
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates                        df
# 99 2010-08-21 18:10:00+00:00 2010-08-21 18:10:00+00:00
# 98 2010-08-23 14:45:49+00:00 2010-08-23 14:45:49+00:00
# 97 2010-08-24 16:26:53+00:00 2010-08-24 16:26:53+00:00
# ...

# %%
test['Dates']
# Out:
# 99   2010-08-21 18:10:00+00:00
# 98   2010-08-23 14:45:49+00:00
# 97   2010-08-24 16:26:53+00:00
# 96   2010-08-24 17:33:20+00:00
# 95   2010-08-25 02:03:08+00:00
#                 ...
# 4    2010-10-16 18:50:42+00:00
# 3    2010-10-17 19:26:05+00:00
# 2    2010-10-17 23:42:03+00:00
# 1    2010-10-18 22:17:43+00:00
# 0    2010-10-19 23:55:27+00:00
# Name: Dates, Length: 100, dtype: datetime64[ns, UTC]

# %%
i=0
print(((test['Dates'][i+1] - test['Dates'][i])).time())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-d0985d4657dd> in <module>
#       1 i=0
# ----> 2 print(((test['Dates'][i+1] - test['Dates'][i])).time())
#
# AttributeError: 'Timedelta' object has no attribute 'time'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-a983a4adaafb> in <module>
# ...

# %%
test
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates  df
# 99 2010-08-21 18:10:00+00:00   0
# 98 2010-08-23 14:45:49+00:00   0
# 97 2010-08-24 16:26:53+00:00   0
# 96 2010-08-24 17:33:20+00:00   0
# 95 2010-08-25 02:03:08+00:00   0
# ...

# %%
i=97
import datetime
print((datetime.datetime.min - (test['Dates'][i+1] - test['Dates'][i])).time())
# Out:
# 01:41:04

# %%
test.shape
# Out:
# (100, 7)

# %%
(test.shape[0] - 1)
# Out:
# 99

# %%
import datetime
for i in range((test.shape[0] - 1)):
    #print(i,"####",(datetime.datetime.min -  (test['Dates'][i+1] - test['Dates'][i])).time())
    test['df'][i] = (datetime.datetime.min -  (test['Dates'][i+1] - test['Dates'][i])).time()
test
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates        df
# 99 2010-08-21 18:10:00+00:00  20:35:49
# 98 2010-08-23 14:45:49+00:00  20:35:49
# 97 2010-08-24 16:26:53+00:00  01:41:04
# 96 2010-08-24 17:33:20+00:00  01:06:27
# ...

# %%
def fun2(fromdate,fromtime,todate,totime):
    fromd=fromdate+fromtime
    tod=todate+totime
    print(test.loc[(df_100['Dates'] > fromd) & (test['Dates'] <= tod)])
    
    
fun2('2010-9-1', ' 5:00:00','2010-10-15',' 22:02:11')
# Out:
#     row                  Date        Lat       long   loc id  \
# 79    0  2010-09-01T22:36:33Z  30.310153 -97.740158  1067829
# 78    0  2010-09-03T00:28:30Z  30.268696 -97.745615     9313
# 77    0  2010-09-04T03:14:33Z  30.266891 -97.745686     9223
# 76    0  2010-09-04T21:32:40Z  30.244860 -97.757163    18417
# 75    0  2010-09-05T17:33:43Z  30.234214 -97.757571  1576090
# ..  ...                   ...        ...        ...      ...
# 9     0  2010-10-12T15:19:03Z  30.269103 -97.749395   420315
# 8     0  2010-10-12T15:57:20Z  30.281120 -97.745211   153505
# 7     0  2010-10-12T19:44:40Z  30.269103 -97.749395   420315
# 6     0  2010-10-12T22:02:11Z  30.267910 -97.749312    21714
# 5     0  2010-10-12T23:58:03Z  30.261599 -97.758581    15372
#
#                        Dates        df
# 79 2010-09-01 22:36:33+00:00  21:28:18
# 78 2010-09-03 00:28:30+00:00  01:51:57
# 77 2010-09-04 03:14:33+00:00  02:46:03
# 76 2010-09-04 21:32:40+00:00  18:18:07
# ...

# %%
import datetime
test[(test["df"] > pd.to_datetime("01:00:44").time()) & (test["loc id"]== 420315)]
# Out:
#     row                  Date        Lat       long  loc id  \
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395  420315
# 94    0  2010-08-25T18:59:04Z  30.269103 -97.749395  420315
# 81    0  2010-08-31T16:19:01Z  30.269103 -97.749395  420315
# 73    0  2010-09-07T16:12:49Z  30.269103 -97.749395  420315
# 72    0  2010-09-07T21:08:32Z  30.269103 -97.749395  420315
# 71    0  2010-09-08T16:58:19Z  30.269103 -97.749395  420315
# 60    0  2010-09-15T23:04:13Z  30.269103 -97.749395  420315
# 53    0  2010-09-24T21:32:13Z  30.269103 -97.749395  420315
# 49    0  2010-09-27T14:52:01Z  30.269103 -97.749395  420315
# 40    0  2010-10-05T16:10:35Z  30.269103 -97.749395  420315
# 9     0  2010-10-12T15:19:03Z  30.269103 -97.749395  420315
# 7     0  2010-10-12T19:44:40Z  30.269103 -97.749395  420315
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395  420315
#
#                        Dates        df
# 97 2010-08-24 16:26:53+00:00  01:41:04
# 94 2010-08-25 18:59:04+00:00  16:55:56
# ...

# %%
test['df'] = pd.to_datetime(test['df'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-da78fe8817a7> in <module>
# ----> 1 test['df'] = pd.to_datetime(test['df'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     726             result = arg.map(cache_array)
#     727         else:
# --> 728             values = convert_listlike(arg._values, format)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
# ...

# %%
test["df"]
# Out:
# 99                     20:35:49
# 98                     01:41:04
# 97                     01:06:27
# 96                     08:29:48
# 95                     16:55:56
#                 ...
# 4                      00:35:23
# 3                      04:15:58
# 2                      22:35:40
# 1                      01:37:44
# 0     2010-10-19 23:55:27+00:00
# Name: df, Length: 100, dtype: object

# %%
test
# Out:
#     row                  Date        Lat       long   loc id  \
# 99    0  2010-08-21T18:10:00Z  30.244860 -97.757163    18417
# 98    0  2010-08-23T14:45:49Z  30.267910 -97.749312    21714
# 97    0  2010-08-24T16:26:53Z  30.269103 -97.749395   420315
# 96    0  2010-08-24T17:33:20Z  30.270734 -97.753703     9241
# 95    0  2010-08-25T02:03:08Z  30.263775 -97.770660     9263
# ..  ...                   ...        ...        ...      ...
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
#
#                        Dates                         df
# 99 2010-08-21 18:10:00+00:00                   20:35:49
# 98 2010-08-23 14:45:49+00:00                   01:41:04
# 97 2010-08-24 16:26:53+00:00                   01:06:27
# ...

# %%
test=df_100.copy()

# %%
test=test.set_index("Dates")

# %%
test
# Out:
#                            row                  Date        Lat       long  \
# Dates
# 2010-10-19 23:55:27+00:00    0  2010-10-19T23:55:27Z  30.235909 -97.795140
# 2010-10-18 22:17:43+00:00    0  2010-10-18T22:17:43Z  30.269103 -97.749395
# 2010-10-17 23:42:03+00:00    0  2010-10-17T23:42:03Z  30.255731 -97.763386
# 2010-10-17 19:26:05+00:00    0  2010-10-17T19:26:05Z  30.263418 -97.757597
# 2010-10-16 18:50:42+00:00    0  2010-10-16T18:50:42Z  30.274292 -97.740523
# ...                        ...                   ...        ...        ...
# 2010-08-25 02:03:08+00:00    0  2010-08-25T02:03:08Z  30.263775 -97.770660
# 2010-08-24 17:33:20+00:00    0  2010-08-24T17:33:20Z  30.270734 -97.753703
# 2010-08-24 16:26:53+00:00    0  2010-08-24T16:26:53Z  30.269103 -97.749395
# 2010-08-23 14:45:49+00:00    0  2010-08-23T14:45:49Z  30.267910 -97.749312
# 2010-08-21 18:10:00+00:00    0  2010-08-21T18:10:00Z  30.244860 -97.757163
#
#                             loc id      Time
# Dates
# ...

# %%
test.min()
# Out:
# row                          0
# Date      2010-08-21T18:10:00Z
# Lat                    30.2314
# long                  -97.8784
# loc id                    8938
# Time                  00:04:39
# dtype: object

# %%
test.max()
# Out:
# row                          0
# Date      2010-10-19T23:55:27Z
# Lat                    40.7808
# long                  -73.7828
# loc id                 5535878
# Time                  23:58:03
# dtype: object

# %%
df_100=df_100.drop(['Date','Lat','long'],axis=1)

# %%
df_100
# Out:
#     row   loc id      Time       Dates
# 0     0    22847  23:55:27  2010-10-19
# 1     0   420315  22:17:43  2010-10-18
# 2     0   316637  23:42:03  2010-10-17
# 3     0    16516  19:26:05  2010-10-17
# 4     0  5535878  18:50:42  2010-10-16
# ..  ...      ...       ...         ...
# 95    0     9263  02:03:08  2010-08-25
# 96    0     9241  17:33:20  2010-08-24
# 97    0   420315  16:26:53  2010-08-24
# 98    0    21714  14:45:49  2010-08-23
# 99    0    18417  18:10:00  2010-08-21
#
# [100 rows x 4 columns]

# %%
grouped = df_100.groupby('loc id')

# %%
print(grouped['loc id'])

# %%
#gb = df_100.groups

for key, item in grouped:
    print(grouped.get_group(key), "\n\n")
# Out:
#     row  loc id      Time       Dates
# 64    0    8938  16:49:55  2010-09-12
#
#
#     row  loc id      Time       Dates
# 63    0    8964  01:13:03  2010-09-13
#
#
#     row  loc id      Time       Dates
# 77    0    9223  03:14:33  2010-09-04
#
#
#     row  loc id      Time       Dates
# 91    0    9225  22:47:32  2010-08-26
#
#
#     row  loc id      Time       Dates
# 96    0    9241  17:33:20  2010-08-24
#
#
#     row  loc id      Time       Dates
# 74    0    9263  00:07:17  2010-09-06
# 86    0    9263  19:16:11  2010-08-28
# 95    0    9263  02:03:08  2010-08-25
#
#
#     row  loc id      Time       Dates
# 78    0    9313  00:28:30  2010-09-03
#
#
#     row  loc id      Time       Dates
# 84    0    9508  00:11:01  2010-08-30
#
#
#     row  loc id      Time       Dates
# 24    0   11742  21:48:37  2010-10-08
#
#
#     row  loc id      Time       Dates
# 27    0   11794  21:43:02  2010-10-08
#
#
#     row  loc id      Time       Dates
# 23    0   11844  01:37:03  2010-10-09
# ...

# %%
keys = grouped.groups.keys()
print(keys)
for i in keys: 
    #print(type(grouped.get_group(i)) )
    print(i)
    print('\n')
# Out:
# dict_keys([8938, 8964, 9223, 9225, 9241, 9263, 9313, 9508, 11742, 11794, 11844, 11934, 12313, 12973, 15079, 15169, 15372, 15590, 16397, 16431, 16516, 16907, 17236, 17526, 17602, 17710, 18329, 18417, 19224, 19822, 21714, 22806, 22847, 23261, 24276, 25151, 27836, 34484, 34817, 35513, 46946, 49215, 60450, 64830, 87914, 105068, 121955, 153505, 157923, 211286, 232292, 260957, 316637, 341255, 420315, 480992, 539065, 1067829, 1145567, 1151119, 1365909, 1567837, 1576090, 1933724, 2587024, 2587606, 3842712, 4256132, 5535878])
# 8938
#
#
# 8964
#
#
# 9223
#
#
# 9225
#
#
# 9241
#
#
# 9263
#
#
# 9313
#
#
# 9508
#
#
# 11742
#
#
# 11794
#
#
# 11844
#
#
# 11934
#
#
# 12313
#
#
# 12973
#
#
# 15079
#
#
# 15169
#
#
# 15372
#
#
# 15590
#
#
# 16397
#
#
# 16431
#
#
# 16516
#
#
# 16907
#
#
# 17236
#
#
# 17526
#
#
# 17602
#
#
# 17710
#
#
# 18329
#
#
# 18417
#
#
# 19224
#
#
# 19822
#
#
# 21714
#
#
# 22806
#
#
# 22847
#
#
# 23261
#
#
# 24276
#
#
# 25151
#
#
# 27836
#
#
# 34484
#
#
# 34817
#
#
# 35513
#
#
# ...

# %%
for i , v in keys.items():
    print(i,v)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-192-898dc77462c8> in <module>
# ----> 1 for i , v in keys.items():
#       2     print(i,v)
#       3
#
# AttributeError: 'dict_keys' object has no attribute 'items'

# %%
for x in grouped.get_group(dict([x for x in keys])):
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-206-ae8131d28372> in <module>
# ----> 1 for x in grouped.get_group(dict_keys([x for x in keys])):
#       2     print(x)
#
# NameError: name 'dict_keys' is not defined

# %%
 print(df_100)
# Out:
#    row  loc id      Time       Dates
# 0    0   22847  23:55:27  2010-10-19
# 1    0  420315  22:17:43  2010-10-18

# %%
x=df_100[

# %%
#df_100=df_100.set_index(df_100['loc id'])

# %%
df_100=df_100.drop(['Date','Lat','long'],axis=1).head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-1e37ea2e865f> in <module>
# ----> 1 df_100=df_100.drop(['Date','Lat','long'],axis=1).head(2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
#for x in df_100:
print(df_100.loc[df_100["loc id"]==420315],"\n")
# Out:
#         row  loc id      Time       Dates
# loc id
# 420315    0  420315  22:17:43  2010-10-18

# %%
#df_100=df.rename(columns={'loc id': 'id'})

# %%
df_100
# Out:
#             row                  Date        Lat       long       id
# 0             0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
# 1             0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 2             0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 3             0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 4             0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# ...         ...                   ...        ...        ...      ...
# 6442887  196578  2010-06-11T13:32:26Z  51.742988  -0.488065   906885
# 6442888  196578  2010-06-11T13:26:45Z  51.746492  -0.490780   965121
# 6442889  196578  2010-06-11T13:26:34Z  51.741916  -0.496729  1174322
# 6442890  196585  2010-10-08T21:01:49Z  50.105516   8.571525   471724
# 6442891  196585  2010-10-07T17:39:18Z  50.027812   8.785098  4555073
#
# [6442892 rows x 5 columns]

# %%
#df_100=df_100.drop('loc id',axis=1).head(2)

# %%
df_100
# Out:
#         row      Time       Dates
# loc id
# 22847     0  23:55:27  2010-10-19
# 420315    0  22:17:43  2010-10-18

# %%
def find(locid):
    print(df_100.loc[df_100["loc id"]==locid].nunique(),"\n")
    print(df_100.loc[df_100["loc id"]==locid])
    #print(screenshot.groupby(['loc id', 'Dates']).count())
find(420315)
# Out:
# row       1
# loc id    1
# Time      1
# Dates     1
# dtype: int64
#
#         row  loc id      Time       Dates
# loc id
# 420315    0  420315  22:17:43  2010-10-18

# %%
# Out:
# <ipython-input-81-d364514d9bda>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   screenshot['Time']=pd.to_datetime(df['Date']).dt.time

# %%
print(screenshot['Time'])
# Out:
# 0     23:55:27
# 1     22:17:43
# 2     23:42:03
# 3     19:26:05
# 4     18:50:42
#         ...
# 95    02:03:08
# 96    17:33:20
# 97    16:26:53
# 98    14:45:49
# 99    18:10:00
# Name: Time, Length: 100, dtype: object

# %%
# Out:
# <ipython-input-83-b78579cacb73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   screenshot['Dates'] = pd.to_datetime(df['Date']).dt.date

# %%
print(screenshot['Dates'])
# Out:
# 0     2010-10-19
# 1     2010-10-18
# 2     2010-10-17
# 3     2010-10-17
# 4     2010-10-16
#          ...
# 95    2010-08-25
# 96    2010-08-24
# 97    2010-08-24
# 98    2010-08-23
# 99    2010-08-21
# Name: Dates, Length: 100, dtype: object

# %%
z=screenshot.groupby(['loc id', 'Dates']).count()
f=screenshot['loc id'].unique()
print(f)
# Out:
# [  22847  420315  316637   16516 5535878   15372   21714  153505   23261
#    16907   12973  341255  260957 1933724  105068   34817   27836   15079
#    22806 1365909   11844   11742   19822   15169   11794 1567837   35513
#    87914   16397   17710   60450   12313   34484   49215   16431   18417
#  1151119 4256132  211286  539065   15590  121955   25151 1145567   46946
#    24276 3842712   17602   17236    8964    8938   19224  157923   18329
#    17526  232292   64830    9263 1576090    9223    9313 1067829  480992
#     9508 2587606 2587024   11934    9225    9241]

# %%
screenshot=screenshot.set_index(screenshot['loc id'])

# %%
#z.to_dict()
# Out:
# {'row': {(8938, datetime.date(2010, 9, 12)): 1,
#   (8964, datetime.date(2010, 9, 13)): 1,
#   (9223, datetime.date(2010, 9, 4)): 1,
#   (9225, datetime.date(2010, 8, 26)): 1,
#   (9241, datetime.date(2010, 8, 24)): 1,
#   (9263, datetime.date(2010, 8, 25)): 1,
#   (9263, datetime.date(2010, 8, 28)): 1,
#   (9263, datetime.date(2010, 9, 6)): 1,
#   (9313, datetime.date(2010, 9, 3)): 1,
#   (9508, datetime.date(2010, 8, 30)): 1,
#   (11742, datetime.date(2010, 10, 8)): 1,
#   (11794, datetime.date(2010, 10, 8)): 1,
#   (11844, datetime.date(2010, 10, 9)): 1,
#   (11934, datetime.date(2010, 8, 28)): 1,
#   (12313, datetime.date(2010, 10, 7)): 1,
#   (12973, datetime.date(2010, 10, 11)): 1,
#   (15079, datetime.date(2010, 10, 9)): 2,
#   (15169, datetime.date(2010, 10, 8)): 1,
#   (15372, datetime.date(2010, 10, 12)): 1,
#   (15590, datetime.date(2010, 9, 28)): 1,
#   (16397, datetime.date(2010, 10, 7)): 1,
#   (16431, datetime.date(2010, 10, 5)): 1,
# ...

# %%
for loc in screenshot:
    if loc == 15079 and :
        print(screenshot.loc[loc],"\n")
        
        
        
        
# df.loc[df['column name'] condition, 'new column name'] = 'value if condition is met'
# Out:
#         row                  Date        Lat       long  loc id      Time  \
# loc id
# 15079     0  2010-10-09T21:39:26Z  40.742396 -74.007543   15079  21:39:26
# 15079     0  2010-10-09T21:36:05Z  40.742396 -74.007543   15079  21:36:05
#
#              Dates
# loc id
# 15079   2010-10-09
# 15079   2010-10-09
#
#         row                  Date        Lat       long  loc id      Time  \
# loc id
# 15079     0  2010-10-09T21:39:26Z  40.742396 -74.007543   15079  21:39:26
# 15079     0  2010-10-09T21:36:05Z  40.742396 -74.007543   15079  21:36:05
#
#              Dates
# loc id
# 15079   2010-10-09
# 15079   2010-10-09

# %%
for x in f:
    if x==15079:
        print(z["row"][x])
# Out:
# Dates
# 2010-10-09    2
# Name: row, dtype: int64

# %%
for x in f:
    if f["loc id"]=="9223":
        print(f["Dates"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7f6b77eb60d8> in <module>
#       1 for x in f:
# ----> 2     if f["loc id"]=="9223":
#       3         print(f["Dates"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1476
#    1477     def __nonzero__(self):
# -> 1478         raise ValueError(
#    1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-f0561b938901> in <module>
# ----> 1 print(screenshot["loc id"].unique.screenshot.groupby(['loc id', 'Dates','Time']).count())
#
# AttributeError: 'function' object has no attribute 'screenshot'

# %%
# Out:
#                     row  Date  Lat  long  Time
# loc id  Dates
# 15372   2010-10-12    1     1    1     1     1
# 16516   2010-10-17    1     1    1     1     1
# 21714   2010-10-12    1     1    1     1     1
# 22847   2010-10-19    1     1    1     1     1
# 153505  2010-10-12    1     1    1     1     1
# 316637  2010-10-17    1     1    1     1     1
# 420315  2010-10-12    2     2    2     2     2
#         2010-10-18    1     1    1     1     1
# 5535878 2010-10-16    1     1    1     1     1

# %%
print(z)
# Out:
#                     row  Date  Lat  long  Time
# loc id  Dates
# 15372   2010-10-12    1     1    1     1     1
# 16516   2010-10-17    1     1    1     1     1
# 21714   2010-10-12    1     1    1     1     1
# 22847   2010-10-19    1     1    1     1     1
# 153505  2010-10-12    1     1    1     1     1
# 316637  2010-10-17    1     1    1     1     1
# 420315  2010-10-12    2     2    2     2     2
#         2010-10-18    1     1    1     1     1
# 5535878 2010-10-16    1     1    1     1     1

# %%
screenshot[["Date1"],["time"]]=screenshot.Date.apply(lambda x: pd.Series(str(x).split("T")))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-d2821852ce2b> in <module>
# ----> 1 screenshot[["Date1"],["time"]]=screenshot.Date.apply(lambda x: pd.Series(str(x).split("T")))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3664
# ...

# %%
print(df)

# %%
y=df.head(10)

# %%
print("hello")

# %%
df
# Out:
#             row                  Date        Lat       long   loc id
# 0             0  2010-10-19T23:55:27Z  30.235909 -97.795140    22847
# 1             0  2010-10-18T22:17:43Z  30.269103 -97.749395   420315
# 2             0  2010-10-17T23:42:03Z  30.255731 -97.763386   316637
# 3             0  2010-10-17T19:26:05Z  30.263418 -97.757597    16516
# 4             0  2010-10-16T18:50:42Z  30.274292 -97.740523  5535878
# ...         ...                   ...        ...        ...      ...
# 6442887  196578  2010-06-11T13:32:26Z  51.742988  -0.488065   906885
# 6442888  196578  2010-06-11T13:26:45Z  51.746492  -0.490780   965121
# 6442889  196578  2010-06-11T13:26:34Z  51.741916  -0.496729  1174322
# 6442890  196585  2010-10-08T21:01:49Z  50.105516   8.571525   471724
# 6442891  196585  2010-10-07T17:39:18Z  50.027812   8.785098  4555073
#
# [6442892 rows x 5 columns]
